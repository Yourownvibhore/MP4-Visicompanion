# %%
# !nvidia-smi
# Out:
# Wed Dec 11 04:59:19 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics

# from IPython import display
# display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="ktqrEfx5nd7CMRBpmvwY")
# project = rf.workspace("vibhore").project("swachmukhh")
# version = project.version(2)
# dataset = version.download("yolov8")

# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="ktqrEfx5nd7CMRBpmvwY")
# project = rf.workspace("vibhore").project("grocery_items-7i2em-ykrxo")
# version = project.version(2)
# dataset = version.download("yolov8")\
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="ktqrEfx5nd7CMRBpmvwY")
# project = rf.workspace("vibhore").project("grocery_items-7i2em-ykrxo")
# version = project.version(2)
# dataset = version.download("yolov8")


# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="NvfmxDBNOxfip2xfuANl")
# project = rf.workspace("new-workspace-wfzw3").project("grocery-dataset-q9fj2")
# version = project.version(5)
# dataset = version.download("yolov8")

# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="NvfmxDBNOxfip2xfuANl")
# project = rf.workspace("new-workspace-wfzw3").project("grocery-dataset-q9fj2")
# version = project.version(4)
# dataset = version.download("yolov8")

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="cM0EvGsfXDButLX67Ddn")
project = rf.workspace("lets-go-nh3ja").project("proj-f1dq8")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to proj-1 in yolov8:: 100%|██████████| 7184/7184 [00:01<00:00, 5829.96it/s]

# %%
# cuda.empty_cache()
# import os

# os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:<enter-size-here>"

# %%
# torch.cuda.empty_cache()

# %%
# !pip install numpy==1.23.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 71.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.23.4 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.4 which is incompatible.
# bigframes 1.27.0 requires numpy>=1.24.0, but you have numpy 1.23.4 which is incompatible.
# chex 0.1.87 requires numpy>=1.24.1, but you have numpy 1.23.4 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.4 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.4 which is incompatible.
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/proj-1/data.yaml epochs=10 imgsz=800 plots=True batch=32

# !yolo task=detect mode=train model=yolov8s.pt data=/content/Grocery_Items-2/data.yaml epochs=10 imgsz=800 plots=True
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# model=YOLO()
# model.train(data='/content/Grocery_Items-2/data.yaml', epochs=10, imgsz=800, plots=True)

# %%
# prompt: download run folder

from google.colab import files
import os

# Define the folder you want to download
folder_to_download = "/content/runs"  # Replace with the actual path

# Create a zip file of the folder
# !zip -r /content/runs.zip /content/runs

# Download the zip file
files.download("/content/runs.zip")
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/val_batch0_pred.jpg (deflated 14%)
#   adding: content/runs/detect/train2/val_batch1_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 9%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 28%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train2/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train2/val_batch0_labels.jpg (deflated 14%)
#   adding: content/runs/detect/train2/PR_curve.png (deflated 19%)
#   adding: content/runs/detect/train2/train_batch0.jpg (deflated 9%)
#   adding: content/runs/detect/train2/labels_correlogram.jpg (deflated 41%)
#   adding: content/runs/detect/train2/P_curve.png (deflated 20%)
# ...

# %%
from IPython.display import display, Image
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png', width=600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/data.yaml

# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data=/content/proj-1/data.yaml
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/proj-1/valid/labels.cache... 415 images, 0 backgrounds, 0 corrupt: 100% 415/415 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 26/26 [00:09<00:00,  2.87it/s]
#                    all        415        416      0.998      0.998      0.994      0.943
#    Coca Cola Can 250ml         63         64      0.998      0.984      0.991      0.942
#            Colgate 75g         59         59      0.998          1      0.995      0.921
#            Fanta 500ml         54         54      0.996          1      0.995      0.967
#            Lays Masala         63         63      0.998          1      0.995      0.972
# Lays Wavy Mexican Chili 34gm         55         55      0.997          1      0.995      0.985
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/test/images save=True

# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/proj-1/test/images save=True
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/199 /content/proj-1/test/images/IMG_0597_jpg.rf.8691e607296dcef682994777e7cc055e.jpg: 800x800 1 Colgate 75g, 22.8ms
# image 2/199 /content/proj-1/test/images/IMG_0599_jpg.rf.2c02a786b8ff9dda479d0ea957a98f94.jpg: 800x800 1 Colgate 75g, 22.8ms
# image 3/199 /content/proj-1/test/images/IMG_0612_jpg.rf.a3e13a6b7d211f7c06448aed05d2cbc1.jpg: 800x800 1 Colgate 75g, 22.8ms
# image 4/199 /content/proj-1/test/images/IMG_0621_jpg.rf.db161e599570b27b10e92836c26c4cc4.jpg: 800x800 1 Colgate 75g, 22.8ms
# image 5/199 /content/proj-1/test/images/IMG_0644_jpg.rf.c3f4dd0461e7679fa2bd58021ad0af79.jpg: 800x800 1 Colgate 75g, 22.8ms
# image 6/199 /content/proj-1/test/images/IMG_0645_jpg.rf.28e79fd0811e836ade2f654afd9a1b27.jpg: 800x800 1 Colgate 75g, 22.8ms
# ...

# %%
# prompt: download run folder

from google.colab import files
import os

# Define the folder you want to download
folder_to_download = "/content/runs"  # Replace with the actual path

# Create a zip file of the folder
# !zip -r /content/runs.zip /content/runs

# Download the zip file
files.download("/content/runs.zip")

# %%
# prompt: download runs folder

# !zip -r /content/runs.zip /content/runs
from google.colab import files
files.download("/content/runs.zip")
# Out:
# updating: content/runs/ (stored 0%)
# updating: content/runs/detect/ (stored 0%)
# updating: content/runs/detect/train2/ (stored 0%)
# updating: content/runs/detect/train2/val_batch0_pred.jpg (deflated 14%)
# updating: content/runs/detect/train2/val_batch1_pred.jpg (deflated 8%)
# updating: content/runs/detect/train2/train_batch2.jpg (deflated 9%)
# updating: content/runs/detect/train2/labels.jpg (deflated 28%)
# updating: content/runs/detect/train2/weights/ (stored 0%)
# updating: content/runs/detect/train2/weights/best.pt (deflated 8%)
# updating: content/runs/detect/train2/weights/last.pt (deflated 8%)
# updating: content/runs/detect/train2/val_batch0_labels.jpg (deflated 14%)
# updating: content/runs/detect/train2/PR_curve.png (deflated 19%)
# updating: content/runs/detect/train2/train_batch0.jpg (deflated 9%)
# updating: content/runs/detect/train2/labels_correlogram.jpg (deflated 41%)
# updating: content/runs/detect/train2/P_curve.png (deflated 20%)
# ...

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"/content/runs/detect/train2/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-67280d213c66> in <cell line: 1>()
# ----> 1 project.version(dataset.version).deploy(model_type="yolov8", model_path=f"/content/runs/detect/train2/")
#
# NameError: name 'project' is not defined

# %%
import glob
from IPython.display import Image, display

# for image_path in glob.glob(f'{HOME}/runs/detect/predict3/*.jpg')[:3]:
#       display(Image(filename=image_path, width=600))
#       print("\n")

# %%
# !zip -r /content/runs.zip /content/runs
# from google.colab import files
# files.download("/content/runs.zip")

# %%
# !pip install roboflow --quiet

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="cM0EvGsfXDButLX67Ddn")
project = rf.workspace("lets-go-nh3ja").project("proj-f1dq8")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
dataset = project.version(1).download("yolov8")

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ktqrEfx5nd7CMRBpmvwY")
project = rf.workspace("vibhore").project("swachmukhh")
version = project.version(1)
dataset = version.download("yolov8")

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"/content/runs/detect/train2/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.3.49, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/lets-go-nh3ja/proj-f1dq8/1
# Share your model with the world at: https://universe.roboflow.com/lets-go-nh3ja/proj-f1dq8/model/1
